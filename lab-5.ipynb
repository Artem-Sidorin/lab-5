# %% [markdown]
# ## Лабораторная работа №5

# %% [markdown]
# ### Задание 1
# Считать в pandas DataFrame любой источник данных: CSV, JSON, Excel-файл, HTML-таблицу, встроенный датасет sklearn. Опишите ваши данные, что обозначает каждый столбец, какого типа (категориальный, вещественный, целочисленный, бинарный) данный столбец, при необходимости для категориальных в том числе бинарных признаков привести расшифровку их значений. В общем, проведите "визуальный" анализ ваших данных.

# %% [markdown]
# Name — название игры
#
# Platform — платформа
#
# Year_of_Release — год выпуска
#
# Genre — жанр игры
#
# NA_sales — продажи в Северной Америке (миллионы долларов)
#
# EU_sales — продажи в Европе (миллионы долларов)
#
# JP_sales — продажи в Японии (миллионы долларов)
#
# Other_sales — продажи в других странах (миллионы долларов)
#
# Critic_Score — оценка критиков (от 0 до 100)
#
# User_Score — оценка пользователей (от 0 до 10)
#
# Rating — рейтинг от организации ESRB (возростная категория)

# %%
import numpy as np
import pandas as pd
import random

# %%
games = pd.read_csv('games.csv')

df_games = pd.DataFrame(data=games)

df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Задание 2
# Выполните с датафреймом следующие операции (многие операции можно совершить не одним способом, используйте все известные вам способы, поищите/придумайте новые способы) :

# %% [markdown]
# ##### 2.1 вывод таблицы

# %%
df_games
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
#        NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score  \
# 0         41.36     28.96      3.77         8.45          76.0          8
# 1         29.08      3.58      6.81         0.77           NaN        NaN
# 2         15.68     12.76      3.79         3.29          82.0        8.3
# 3         15.61     10.93      3.28         2.95          80.0          8
# 4         11.27      8.89     10.22         1.00           NaN        NaN
# ...         ...       ...       ...          ...           ...        ...
# 16710      0.00      0.00      0.01         0.00           NaN        NaN
# 16711      0.00      0.01      0.00         0.00           NaN        NaN
# 16712      0.00      0.00      0.01         0.00           NaN        NaN
# 16713      0.01      0.00      0.00         0.00           NaN        NaN
# 16714      0.00      0.00      0.01         0.00           NaN        NaN
#
#       Rating
# 0          E
# 1        NaN
# 2          E
# 3          E
# 4        NaN
# ...      ...
# 16710    NaN
# 16711    NaN
# 16712    NaN
# 16713    NaN
# 16714    NaN
#
# [16715 rows x 11 columns]

# %% [markdown]
# ##### 2.2 вывод первых 5 элементов таблицы

# %%
df_games.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# ##### 2.3 вывод последних 5 элементов таблицы

# %%
df_games.tail(5)
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16711               LMA Manager 2007     X360           2006.0      Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16713               Spirits & Spells      GBA           2003.0    Platform
# 16714            Winning Post 8 2016      PSV           2016.0  Simulation
#
#        NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score  \
# 16710      0.00      0.00      0.01          0.0           NaN        NaN
# 16711      0.00      0.01      0.00          0.0           NaN        NaN
# 16712      0.00      0.00      0.01          0.0           NaN        NaN
# 16713      0.01      0.00      0.00          0.0           NaN        NaN
# 16714      0.00      0.00      0.01          0.0           NaN        NaN
#
#       Rating
# 16710    NaN
# 16711    NaN
# 16712    NaN
# 16713    NaN
# 16714    NaN

# %% [markdown]
# ##### 2.4 использовать функцию describe()

# %%
df_games.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# ##### 2.5 считывание значения конкретной ячейки (с конкретным индексом из конкретной колонки) всеми известными вам способами

# %%
df_games.iloc[2023]['Name']
# Out:
# 'Shrek 2'

# %%
df_games.at[2023,'Genre']
# Out:
# 'Platform'

# %%
df_games['Critic_Score'].values[2023]
# Out:
# 70.0

# %%
df_games._get_value(2023, 'User_Score')
# Out:
# '6.4'

# %% [markdown]
# ##### 2.6 фильтрация строк по диапазону индекса

# %%
df_games[games.index.isin ([i for i in range(2023, 2030)])]
# Out:
#                                                 Name Platform  \
# 2023                                         Shrek 2       GC
# 2024                                        NBA 2K17     XOne
# 2025  Tom Clancy's Ghost Recon Advanced Warfighter 2     X360
# 2026                                 Sonic Unleashed      PS3
# 2027                                   Final Fight 2     SNES
# 2028                   The Lost World: Jurassic Park       PS
# 2029                                 Disney Universe      Wii
#
#       Year_of_Release     Genre  NA_sales  EU_sales  JP_sales  Other_sales  \
# 2023           2004.0  Platform      0.73      0.26      0.01         0.03
# 2024           2016.0    Sports      0.86      0.06      0.00         0.11
# 2025           2007.0   Shooter      0.87      0.05      0.02         0.08
# 2026           2008.0  Platform      0.56      0.32      0.01         0.14
# 2027           1993.0    Action      0.39      0.12      0.49         0.02
# 2028           1997.0    Action      0.57      0.39      0.00         0.07
# 2029           2011.0    Action      0.64      0.28      0.00         0.10
#
#       Critic_Score User_Score Rating
# 2023          70.0        6.4      E
# 2024          90.0        6.2      E
# 2025          86.0        8.1      T
# 2026          54.0        7.9   E10+
# 2027           NaN        NaN    NaN
# 2028           NaN        NaN    NaN
# 2029          61.0          6   E10+

# %% [markdown]
# ##### 2.7 фильтрация набора данных по какому-либо условию

# %%
df_games.loc[(games['Genre']=='Shooter')]
# Out:
#                                                     Name Platform  \
# 9                                              Duck Hunt      NES
# 29                        Call of Duty: Modern Warfare 3     X360
# 31                             Call of Duty: Black Ops 3      PS4
# 32                               Call of Duty: Black Ops     X360
# 34                            Call of Duty: Black Ops II      PS3
# ...                                                  ...      ...
# 16576                DoDonPachi Daifukkatsu: Black Label     X360
# 16577                                      Space Raiders       GC
# 16602  Transformers: War for Cybertron (XBox 360, PS3...       PC
# 16696                                             Breach       PC
# 16706                      Men in Black II: Alien Escape       GC
#
#        Year_of_Release    Genre  NA_sales  EU_sales  JP_sales  Other_sales  \
# 9               1984.0  Shooter     26.93      0.63      0.28         0.47
# 29              2011.0  Shooter      9.04      4.24      0.13         1.32
# 31              2015.0  Shooter      6.03      5.86      0.36         2.38
# 32              2010.0  Shooter      9.70      3.68      0.11         1.13
# 34              2012.0  Shooter      4.99      5.73      0.65         2.42
# ...                ...      ...       ...       ...       ...          ...
# 16576           2011.0  Shooter      0.00      0.00      0.01         0.00
# 16577           2003.0  Shooter      0.01      0.00      0.00         0.00
# 16602           2010.0  Shooter      0.01      0.00      0.00         0.00
# 16696           2011.0  Shooter      0.01      0.00      0.00         0.00
# 16706           2003.0  Shooter      0.01      0.00      0.00         0.00
#
#        Critic_Score User_Score Rating
# 9               NaN        NaN    NaN
# 29             88.0        3.4      M
# 31              NaN        NaN    NaN
# 32             87.0        6.3      M
# 34             83.0        5.3      M
# ...             ...        ...    ...
# 16576           NaN        NaN    NaN
# 16577          40.0        tbd      T
# 16602           NaN        NaN    NaN
# 16696          61.0        5.8      T
# 16706           NaN        tbd      T
#
# [1323 rows x 11 columns]

# %% [markdown]
# ##### 2.8 работа с пропущенными значениями (если они есть): удаление строк с пропущенными значениями, заполнение пропущенных значений средним значением по колонке. Если пропущенных значений нет — намеренно их "генерируете", прибивая какие-то куски данных в np.nan

# %%
df_del_NaN = df_games.dropna()
df_del_NaN
# Out:
#                           Name Platform  Year_of_Release     Genre  NA_sales  \
# 0                   Wii Sports      Wii           2006.0    Sports     41.36
# 2               Mario Kart Wii      Wii           2008.0    Racing     15.68
# 3            Wii Sports Resort      Wii           2009.0    Sports     15.61
# 6        New Super Mario Bros.       DS           2006.0  Platform     11.28
# 7                     Wii Play      Wii           2006.0      Misc     13.96
# ...                        ...      ...              ...       ...       ...
# 16695          Planet Monsters      GBA           2001.0    Action      0.01
# 16696                   Breach       PC           2011.0   Shooter      0.01
# 16697         Bust-A-Move 3000       GC           2003.0    Puzzle      0.01
# 16698         Mega Brain Boost       DS           2008.0    Puzzle      0.01
# 16702  STORM: Frontline Nation       PC           2011.0  Strategy      0.00
#
#        EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0         28.96      3.77         8.45          76.0          8      E
# 2         12.76      3.79         3.29          82.0        8.3      E
# 3         10.93      3.28         2.95          80.0          8      E
# 6          9.14      6.50         2.88          89.0        8.5      E
# 7          9.18      2.93         2.84          58.0        6.6      E
# ...         ...       ...          ...           ...        ...    ...
# 16695      0.00      0.00         0.00          67.0        tbd      E
# 16696      0.00      0.00         0.00          61.0        5.8      T
# 16697      0.00      0.00         0.00          53.0        tbd      E
# 16698      0.00      0.00         0.00          48.0        tbd      E
# 16702      0.01      0.00         0.00          60.0        7.2   E10+
#
# [7878 rows x 11 columns]

# %%
df_change_NaN = df_games['Critic_Score'].fillna(df_games['Critic_Score'].mean())
df_change_NaN
# Out:
# 0        76.000000
# 1        68.967679
# 2        82.000000
# 3        80.000000
# 4        68.967679
#            ...
# 16710    68.967679
# 16711    68.967679
# 16712    68.967679
# 16713    68.967679
# 16714    68.967679
# Name: Critic_Score, Length: 16715, dtype: float64

# %% [markdown]
# ##### 2.9  создание нового поля вычисленного на основе значений других полей:

# %% [markdown]
# ##### 2.9.1 через выражение на базе имеющихся колонок,

# %%
df_games = df_games.assign(Total_summ = df_games.NA_sales + df_games.EU_sales + df_games.JP_sales + df_games.Other_sales)
df_games
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
#        NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score  \
# 0         41.36     28.96      3.77         8.45          76.0          8
# 1         29.08      3.58      6.81         0.77           NaN        NaN
# 2         15.68     12.76      3.79         3.29          82.0        8.3
# 3         15.61     10.93      3.28         2.95          80.0          8
# 4         11.27      8.89     10.22         1.00           NaN        NaN
# ...         ...       ...       ...          ...           ...        ...
# 16710      0.00      0.00      0.01         0.00           NaN        NaN
# 16711      0.00      0.01      0.00         0.00           NaN        NaN
# 16712      0.00      0.00      0.01         0.00           NaN        NaN
# 16713      0.01      0.00      0.00         0.00           NaN        NaN
# 16714      0.00      0.00      0.01         0.00           NaN        NaN
#
#       Rating  Total_summ
# 0          E       82.54
# 1        NaN       40.24
# 2          E       35.52
# 3          E       32.77
# 4        NaN       31.38
# ...      ...         ...
# 16710    NaN        0.01
# 16711    NaN        0.01
# 16712    NaN        0.01
# 16713    NaN        0.01
# 16714    NaN        0.01
#
# [16715 rows x 12 columns]

# %% [markdown]
# ##### 2.9.2 через DataFrame.apply

# %%
df_games['NA_EU_summ'] = df_games.apply(lambda row: row['NA_sales'] + row['EU_sales'], axis = 1)
df_games
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
#        NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score  \
# 0         41.36     28.96      3.77         8.45          76.0          8
# 1         29.08      3.58      6.81         0.77           NaN        NaN
# 2         15.68     12.76      3.79         3.29          82.0        8.3
# 3         15.61     10.93      3.28         2.95          80.0          8
# 4         11.27      8.89     10.22         1.00           NaN        NaN
# ...         ...       ...       ...          ...           ...        ...
# 16710      0.00      0.00      0.01         0.00           NaN        NaN
# 16711      0.00      0.01      0.00         0.00           NaN        NaN
# 16712      0.00      0.00      0.01         0.00           NaN        NaN
# 16713      0.01      0.00      0.00         0.00           NaN        NaN
# 16714      0.00      0.00      0.01         0.00           NaN        NaN
#
#       Rating  RU_sales  NA_EU_summ
# 0          E         1       70.32
# 1        NaN         1       32.66
# 2          E        10       28.44
# 3          E         9       26.54
# 4        NaN         8       20.16
# ...      ...       ...         ...
# 16710    NaN         3        0.00
# 16711    NaN         3        0.01
# 16712    NaN         3        0.00
# 16713    NaN         1        0.01
# 16714    NaN         6        0.00
#
# [16715 rows x 13 columns]

# %% [markdown]
# ##### 2.9.3 через Series.apply

# %%
RU_sales = pd.Series([random.randint(1,10) for i in range(0, len(df_games))])
df_games['RU_sales'] = RU_sales
df_games
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
#        NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score  \
# 0         41.36     28.96      3.77         8.45          76.0          8
# 1         29.08      3.58      6.81         0.77           NaN        NaN
# 2         15.68     12.76      3.79         3.29          82.0        8.3
# 3         15.61     10.93      3.28         2.95          80.0          8
# 4         11.27      8.89     10.22         1.00           NaN        NaN
# ...         ...       ...       ...          ...           ...        ...
# 16710      0.00      0.00      0.01         0.00           NaN        NaN
# 16711      0.00      0.01      0.00         0.00           NaN        NaN
# 16712      0.00      0.00      0.01         0.00           NaN        NaN
# 16713      0.01      0.00      0.00         0.00           NaN        NaN
# 16714      0.00      0.00      0.01         0.00           NaN        NaN
#
#       Rating  RU_sales
# 0          E         1
# 1        NaN         1
# 2          E        10
# 3          E         9
# 4        NaN         8
# ...      ...       ...
# 16710    NaN         3
# 16711    NaN         3
# 16712    NaN         3
# 16713    NaN         1
# 16714    NaN         6
#
# [16715 rows x 12 columns]

# %% [markdown]
# ##### 2.10 сортировка по какому-либо из полей

# %%
df_games.sort_values(by='Year_of_Release')
# Out:
#                                     Name Platform  Year_of_Release  \
# 1764                             Kaboom!     2600           1980.0
# 546                      Missile Command     2600           1980.0
# 1968                            Defender     2600           1980.0
# 6300                              Bridge     2600           1980.0
# 6875                            Checkers     2600           1980.0
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               Genre  NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score  \
# 1764           Misc      1.07      0.07       0.0         0.01           NaN
# 546         Shooter      2.56      0.17       0.0         0.03           NaN
# 1968           Misc      0.99      0.05       0.0         0.01           NaN
# 6300           Misc      0.25      0.02       0.0         0.00           NaN
# 6875           Misc      0.22      0.01       0.0         0.00           NaN
# ...             ...       ...       ...       ...          ...           ...
# 16373        Sports      0.01      0.00       0.0         0.00          43.0
# 16405        Racing      0.01      0.00       0.0         0.00          69.0
# 16448       Shooter      0.01      0.00       0.0         0.00          59.0
# 16458     Adventure      0.01      0.00       0.0         0.00           NaN
# 16522  Role-Playing      0.01      0.00       0.0         0.00          55.0
#
#       User_Score Rating  RU_sales  NA_EU_summ
# 1764         NaN    NaN         4        1.14
# 546          NaN    NaN         4        2.73
# 1968         NaN    NaN         7        1.04
# 6300         NaN    NaN        10        0.27
# 6875         NaN    NaN         3        0.23
# ...          ...    ...       ...         ...
# 16373        tbd   E10+         6        0.01
# 16405        6.5      T         2        0.01
# 16448        6.7      M         3        0.01
# 16458        NaN    NaN         4        0.01
# 16522        5.5      T         6        0.01
#
# [16715 rows x 13 columns]

# %% [markdown]
# ##### 2.11 вычислить несколько статистик по колонкам (используйте встроенные агрегатные функции — любые на выбор)

# %%
df_games.describe(include='object')
# Out:
#                                Name Platform   Genre User_Score Rating
# count                         16713    16715   16713      10014   9949
# unique                        11559       31      12         96      8
# top     Need for Speed: Most Wanted      PS2  Action        tbd      E
# freq                             12     2161    3369       2424   3990

# %%
df_games.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score      RU_sales    NA_EU_summ
# count  16715.000000   8137.000000  16715.000000  16715.000000
# mean       0.047342     68.967679      5.497637      0.408437
# std        0.186731     13.938165      2.864733      1.241828
# min        0.000000     13.000000      1.000000      0.000000
# 25%        0.000000     60.000000      3.000000      0.020000
# 50%        0.010000     71.000000      5.000000      0.110000
# 75%        0.030000     79.000000      8.000000      0.365000
# max       10.570000     98.000000     10.000000     70.320000

# %% [markdown]
# ##### 2.12 value_counts()

# %%
df_games['Genre'].value_counts()
# Out:
# Action          3369
# Sports          2348
# Misc            1750
# Role-Playing    1498
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       873
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: Genre, dtype: int64

# %% [markdown]
# ##### 2.13 Вывод уникальных значений колонки через .unique()

# %%
df_games['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', nan], dtype=object)

# %% [markdown]
# ##### 2.14 Удалите текущий индекс и создайте новый индекс на базе новой колонки, которая для этого лучше всего подходит

# %%
df_games.reset_index(inplace= False)
df_games.set_index('Name')
# Out:
#                               Platform  Year_of_Release         Genre  \
# Name
# Wii Sports                         Wii           2006.0        Sports
# Super Mario Bros.                  NES           1985.0      Platform
# Mario Kart Wii                     Wii           2008.0        Racing
# Wii Sports Resort                  Wii           2009.0        Sports
# Pokemon Red/Pokemon Blue            GB           1996.0  Role-Playing
# ...                                ...              ...           ...
# Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# LMA Manager 2007                  X360           2006.0        Sports
# Haitaka no Psychedelica            PSV           2016.0     Adventure
# Spirits & Spells                   GBA           2003.0      Platform
# Winning Post 8 2016                PSV           2016.0    Simulation
#
#                                NA_sales  EU_sales  JP_sales  Other_sales  \
# Name
# Wii Sports                        41.36     28.96      3.77         8.45
# Super Mario Bros.                 29.08      3.58      6.81         0.77
# Mario Kart Wii                    15.68     12.76      3.79         3.29
# Wii Sports Resort                 15.61     10.93      3.28         2.95
# Pokemon Red/Pokemon Blue          11.27      8.89     10.22         1.00
# ...                                 ...       ...       ...          ...
# Samurai Warriors: Sanada Maru      0.00      0.00      0.01         0.00
# LMA Manager 2007                   0.00      0.01      0.00         0.00
# Haitaka no Psychedelica            0.00      0.00      0.01         0.00
# Spirits & Spells                   0.01      0.00      0.00         0.00
# Winning Post 8 2016                0.00      0.00      0.01         0.00
#
#                                Critic_Score User_Score Rating  RU_sales  \
# Name
# Wii Sports                             76.0          8      E         1
# Super Mario Bros.                       NaN        NaN    NaN         1
# Mario Kart Wii                         82.0        8.3      E        10
# Wii Sports Resort                      80.0          8      E         9
# Pokemon Red/Pokemon Blue                NaN        NaN    NaN         8
# ...                                     ...        ...    ...       ...
# Samurai Warriors: Sanada Maru           NaN        NaN    NaN         3
# LMA Manager 2007                        NaN        NaN    NaN         3
# Haitaka no Psychedelica                 NaN        NaN    NaN         3
# Spirits & Spells                        NaN        NaN    NaN         1
# Winning Post 8 2016                     NaN        NaN    NaN         6
#
#                                NA_EU_summ
# Name
# Wii Sports                          70.32
# Super Mario Bros.                   32.66
# Mario Kart Wii                      28.44
# Wii Sports Resort                   26.54
# Pokemon Red/Pokemon Blue            20.16
# ...                                   ...
# Samurai Warriors: Sanada Maru        0.00
# LMA Manager 2007                     0.01
# Haitaka no Psychedelica              0.00
# Spirits & Spells                     0.01
# Winning Post 8 2016                  0.00
#
# [16715 rows x 12 columns]
